# %% [markdown]
# <a href="https://colab.research.google.com/github/Juancamilo12546/Actividad-CRAI-UNIMINUTO/blob/main/Te_damos_la_bienvenida_a_Colaboratory%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # OPERADORES
#
# ## numb1
# ## numb2

# %%
num1=1
num2=3
suma = num1+num2
print(suma)
print(num1.num2)
print(15-4)
print(15*num2)
print(15%4) #Moudulo de la division o residuo
print(2**4)
# Out:
# 4
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_499/607770091.py in <cell line: 0>()
#       3 suma = num1+num2
#       4 print(suma)
# ----> 5 print(num1.num2)
#       6 print(15-4)
#       7 print(15*num2)
#
# AttributeError: 'int' object has no attribute 'num2'

# %% [markdown]
# # Operadores de *comparacion*

# %%
num1=3
num2=5
num3=4
print(num1==num2)
print(num1 != num2)
print(num1>num2)
print(num1<num2)
print(num1>=num2)
print(num2==num3)
# Out:
# False
# True
# False
# True
# False
# False

# %%
#Operadores logicos AND OR NOT
edad=13
mayoredad= True
print(edad<=13 and mayoredad)
# Out:
# True

# %%
Estrutrura if
# Out:
#   File "/tmp/ipykernel_499/1132321735.py", line 1
#     Estrutrura if
#                  ^
# SyntaxError: invalid syntax

# %%
edad = int(input("Ingrese la edad"))
#print(edad)

if edad>= 18:
  print("Mayor de edad")
elif edad == 12:
    print("Adolecente")
else:
    print("Menor de edad")
# Out:
# Ingrese la edad12
# Adolecente

# %% [markdown]
# # Uso input
