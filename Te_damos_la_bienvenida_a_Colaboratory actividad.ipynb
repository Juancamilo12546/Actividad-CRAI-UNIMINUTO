# %% [markdown]
# <a href="https://colab.research.google.com/github/Juancamilo12546/Actividad-CRAI-UNIMINUTO/blob/main/Te_damos_la_bienvenida_a_Colaboratory%20actividad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Programa de estudiantes que pierde el año,aprueba o recuperacion

# %%
1 nota1 = float(input("Ingrese su nota del primer periodo entre 0 y 5:"))
2 if nota1 >= 3.5:
3  print("Aprueba")
4 elif nota1 <=3.0:
5  print("Recuperacion")
6 elif nota1 2.5 de 5.0:
6 else:
7  print("Pierde el año y tiene que repitirlo")
# Out:
#   File "/tmp/ipykernel_499/2531912045.py", line 1
#     1 nota1 = float(input("Ingrese su nota del primer periodo entre 0 y 5:"))
#       ^
# SyntaxError: invalid syntax
